# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.ticker import MultipleLocator

# %%
## -- load in data from curated npz file
## -- we'll load in the case 2 one, but you could use any of the four
## --      since we're only grabbing the raw light curve
load = np.load('./data/broadband_readysave_case2.npz')
t = load['t'] # times in (MJD)
y = load['y'] # relative fluxes
yerr = load['yerr'] # relative flux uncertainties
del load

# %%
## -- create figure:
fig, ax = plt.subplots(figsize=(5,4))
ax.plot(t, y, ls='None', marker='o', ms=1, c='black', rasterized=True)

ax.set_ylabel("Relative Flux", fontsize=11)
ax.set_xlabel("Time (MJD)", fontsize=11)
ax.ticklabel_format(axis="x", style="plain", useOffset=True, useMathText=True, scilimits=(-5,10))
ax.set_ylim(0.992,1.01)
ax.yaxis.set_major_locator(MultipleLocator(0.002))
plt.savefig('./figures/Figure1.png', dpi=600, bbox_inches='tight')
plt.savefig('./figures/Figure1.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
## -- create figure:
fig, ax = plt.subplots(figsize=(5,4))
ax.plot(t, y, ls='None', marker='o', ms=1, c='black', rasterized=True)
# annotations:
# contact points:
ax.axvline(t[520], c='gray', ymin=0.65, ymax=0.68), ax.text(t[520-40], 1.00275, r't$_1$', fontsize=10, c='gray')
ax.axvline(t[610], c='gray', ymin=0.55, ymax=0.58), ax.text(t[610-40], 1.001, r't$_2$', fontsize=10, c='gray')
ax.axvline(t[1730], c='gray', ymin=0.21, ymax=0.24), ax.text(t[1730-40], 0.9947, r't$_3$', fontsize=10, c='gray')
ax.axvline(t[1820], c='gray', ymin=0.25, ymax=0.28), ax.text(t[1820-30], 0.9955, r't$_4$', fontsize=10, c='gray')
# starspots:
ax.axvline(t[700], c='red', ymin=0.68, ymax=0.71), ax.text(t[700-50], 1.0055, 'SCEs', fontsize=10, c='red')
ax.axvline(t[800], c='red', ymin=0.65, ymax=0.68)
ax.axvline(t[1050], c='red', ymin=0.57, ymax=0.60)
ax.axvline(t[1200], c='red', ymin=0.52, ymax=0.55)
ax.axvline(t[1400],c='red', ymin=0.45, ymax=0.48)
ax.axvline(t[1620],c='red', ymin=0.40, ymax=0.43)
           
ax.set_ylabel("Relative Flux", fontsize=11)
ax.set_xlabel("Time (MJD)", fontsize=11)
ax.ticklabel_format(axis="x", style="plain", useOffset=True, useMathText=True, scilimits=(-5,10))
ax.set_ylim(0.992,1.01)
ax.yaxis.set_major_locator(MultipleLocator(0.002))
plt.savefig('./figures/Figure1_annotated.png', dpi=600, bbox_inches='tight')
plt.savefig('./figures/Figure1_annotated.pdf', dpi=600, bbox_inches='tight')
plt.show()
